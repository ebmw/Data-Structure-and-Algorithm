# %% [markdown]
# In **LaTeX**, you can represent various mathematical symbols and operations, including **union (∪)**, **summation (∑)**, and more. Here’s a list of commonly used mathematical notations:
#
# ---
#
# ### **1. Basic Mathematical Symbols**
# | Symbol  | LaTeX Code  | Meaning |
# |---------|------------|---------|
# | $ + $  | `+` | Addition |
# | $ - $  | `-` | Subtraction |
# | $ \times $  | `\times` | Multiplication |
# | $ \cdot $  | `\cdot` | Dot product |
# | $ \div $  | `\div` | Division |
# | $ \frac{a}{b} $  | `\frac{a}{b}` | Fraction |
# | $ \sqrt{x} $  | `\sqrt{x}` | Square root |
# | $ x^n $  | `x^n` | Exponentiation |
# | $ x_n $  | `x_n` | Subscript |
#
# ---
#
# ### **2. Set Theory Symbols**
# | Symbol  | LaTeX Code  | Meaning |
# |---------|------------|---------|
# | $\cup$  | `\cup` | Union |
# | $ \cap $  | `\cap` | Intersection |
# | $ \subset $  | `\subset` | Subset |
# | $ \supset $  | `\supset` | Superset |
# | $ \subseteq $  | `\subseteq` | Subset or equal |
# | $ \supseteq $  | `\supseteq` | Superset or equal |
# | $ \emptyset $  | `\emptyset` | Empty set |
# | $ \in $  | `\in` | Element of |
# | $ \notin $  | `\notin` | Not an element of |
#
# ---
#
# ### **3. Summation and Product**
# | Symbol  | LaTeX Code  | Meaning |
# |---------|------------|---------|
# | $ \sum_{i=1}^{n} a_i $  | `\sum_{i=1}^{n} a_i` | Summation |
# | $ \prod_{i=1}^{n} a_i $  | `\prod_{i=1}^{n} a_i` | Product |
#
# ---
#
# ### **4. Limits and Integrals**
# | Symbol  | LaTeX Code  | Meaning |
# |---------|------------|---------|
# | $ \lim_{x \to a} f(x) $  | `\lim_{x \to a} f(x)` | Limit |
# | $ \int_{a}^{b} f(x) \,dx $  | `\int_{a}^{b} f(x) \,dx` | Definite integral |
# | $ \int f(x) \,dx $  | `\int f(x) \,dx` | Indefinite integral |
# | $ \oint f(x) \,dx $  | `\oint f(x) \,dx` | Contour integral |
#
# ---
#
# ### **5. Greek Letters**
# | Symbol  | LaTeX Code  | Name |
# |---------|------------|------|
# | $ \alpha $  | `\alpha` | Alpha |
# | $ \beta $  | `\beta` | Beta |
# | $ \gamma $  | `\gamma` | Gamma |
# | $ \delta $  | `\delta` | Delta |
# | $ \lambda $  | `\lambda` | Lambda |
# | $ \pi $  | `\pi` | Pi |
# | $ \theta $  | `\theta` | Theta |
# | $ \sigma $  | `\sigma` | Sigma |
# | $ \omega $  | `\omega` | Omega |
#
# ---
#
# ### **6. Logic and Relations**
# | Symbol  | LaTeX Code  | Meaning |
# |---------|------------|---------|
# | $ \forall $  | `\forall` | For all |
# | $ \exists $  | `\exists` | There exists |
# | $ \Rightarrow $  | `\Rightarrow` | Implies |
# | $ \Leftrightarrow $  | `\Leftrightarrow` | If and only if |
# | $ \neg $  | `\neg` | Negation |
# | $ \land $  | `\land` | And |
# | $ \lor $  | `\lor` | Or |
#
# ---
#
# ### **7. Matrices**
# ```latex
# \begin{bmatrix}
# a & b \\
# c & d
# \end{bmatrix}
# ```
# Renders as:
# \[
# \begin{bmatrix}
# a & b \\
# c & d
# \end{bmatrix}
# \]
#
# ---
#
# ### **8. Big Operators**
# | Symbol  | LaTeX Code  | Meaning |
# |---------|------------|---------|
# | $ \bigcup $  | `\bigcup` | Big union |
# | $ \bigcap $  | `\bigcap` | Big intersection |
# | $ \sum $  | `\sum` | Summation |
# | $ \prod $  | `\prod` | Product |
#
# ---
#
# Do you need help with anything specific in **LaTeX**? 😊

# %% [markdown]
# # EXERCISES
#
# Here are some **mathematical expressions** involving **sets** that you can try writing in LaTeX:
#
# ### **1. Union and Intersection**
# $
# A \cup B = \{ x \mid x \in A \text{ or } x \in B \}
# $
# $
# A \cap B = \{ x \mid x \in A \text{ and } x \in B \}
# $
#
# ### **2. Set Difference**
# $
# A \setminus B = \{ x \mid x \in A \text{ and } x \notin B \}
# $

# %% [markdown]
# ## MY TRY
# - $A \cap B = \{ x \mid x \in A \land x \in B\}$
# - $A \cup B = \{ x \mid x \in A \lor  x \in B \} $
# - $A \setminus B = \{ x \mid x \in A \land x \notin B \}$

# %% [markdown]
# ### **3. Cartesian Product**
# $
# A \times B = \{ (a, b) \mid a \in A, b \in B \}
# $
#
# ### **4. Power Set**
# $
# \mathcal{P}(A) = \{ X \mid X \subseteq A \}
# $
#
# ### **5. De Morgan's Laws**
# $
# (A \cup B)^C = A^C \cap B^C
# $
# $
# (A \cap B)^C = A^C \cup B^C
# $
#
# ### **6. Cardinality of a Set**
# $
# |A \cup B| = |A| + |B| - |A \cap B|
# $
#
# ### **7. Subset Definition**
# $
# A \subseteq B \iff \forall x (x \in A \rightarrow x \in B)
# $
#
# Try writing these in LaTeX! Let me know if you need help formatting them. 🚀

# %% [markdown]
# - $A \times B =  \{ (a,b) \mid a \in A , b \in B \}$
# - $\mathcal {P}(A) = \{ X \mid X \subseteq A\}$
# - $(A \cup B) ^ c = A^c \cap B^c (A\cap B)^c = A^c \cup B^c $
# - $| A \cup B|=|A| +|B| - | A \cap B|$
# - $A \subseteq B \iff \forall x (x\in A \rightarrow x \in B )$

# %% [markdown]
# Here are some **LaTeX exercises** covering different mathematical topics:
#
# ---
#
# ### **1. Quadratic Formula**
# $
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# $
#
# ---
#
# ### **2. Summation and Product Notation**
# $
# \sum_{n=1}^{\infty} \frac{1}{n^2} = \frac{\pi^2}{6}
# $
# $
# \prod_{k=1}^{n} k = n!
# $
#
# ---
#
# ### **3. Limits and Derivatives**
# $
# \lim_{x \to 0} \frac{\sin x}{x} = 1
# $
# $
# \frac{d}{dx} \left( x^n \right) = n x^{n-1}
# $
#
# ---
#
# ### **4. Integrals**
# $
# \int_0^\infty e^{-x} \,dx = 1
# $
# $
# \int_0^1 x^n \,dx = \frac{1}{n+1}, \quad n > -1
# $

# %% [markdown]
# ## My try
# - $x  = \frac {-b \pm \sqrt{b^2 -4ac}}{2a}$
# - $\sum_{n=1}^{\infty} \frac{1}{n^2} = \frac {\pi ^ 2}{6} \prod_ {k=1}^{n} k = n! $
# - $\lim_{x \rightarrow 0 } \frac {sin x} {x} = 1$
# - $\frac {d}{dx} (x^n) = nx^{n-1}$
# - $\int_{0}^{\infty} e^{-x} dx = 1$
# - $\int_{0}{1} x^n dx = \frac {1}{n+1}, \quad n > -1 $

# %% [markdown]
# ---
#
# ### **5. Matrix Representation**
# $
# A = \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{bmatrix}
# $
#
# ---
#
# ### **6. Complex Numbers & Euler’s Formula**
# $
# e^{i\pi} + 1 = 0
# $
# $
# z = a + bi, \quad |z| = \sqrt{a^2 + b^2}
# $
#
# ---
#
# ### **7. Probability & Expectation**
# $
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# $
# $
# E[X] = \sum_{x} x P(X = x)
# $
#
# ---
#
# ### **8. Binomial Theorem**
# $
# (a+b)^n = \sum_{k=0}^{n} \binom{n}{k} a^{n-k} b^k
# $
#
# ---
#
# ### **9. Taylor Series Expansion**
# $
# e^x = \sum_{n=0}^{\infty} \frac{x^n}{n!}
# $
#
# ---
#
# ### **10. Trigonometric Identities**
# $
# \sin^2 x + \cos^2 x = 1
# $
# $
# \tan x = \frac{\sin x}{\cos x}
# $
#
# ---

# %% [markdown]
# $
# A = \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{bmatrix}
# $
#
# $
# B = \begin{bmatrix}
# 6 & 3 & 5 \\
# 2 & 7 & 3 \\
# 0 & 4 & 2
# \end{bmatrix}
# $
# - $e^{i\pi} + 1 = 0 $
# - $(a+b)^n = \sum_{k=0}^n \binom{n}{k}a^{n-k}b^k$
# - $e^x  = \sum_{n=0}^\infty \frac { x^n} {n!}$
# - $\sin^2 x + \cos^2 x = 1$
# - $\tan x = \frac{\sin x} { \cos x}$

# %% [markdown]
# Here are more **LaTeX exercises** covering a variety of mathematical topics. Try writing these in LaTeX and rendering them! 🚀
#
# ---
#
# ### **1. Factorial and Permutations**
# $
# n! = n \times (n-1) \times (n-2) \times \cdots \times 1
# $
#
# $
# P(n, r) = \frac{n!}{(n-r)!}
# $
#
# ---
#
# ### **2. Binomial Theorem Expansion**
# $
# (a + b)^n = \sum_{k=0}^{n} \binom{n}{k} a^{n-k} b^k
# $
#
# ---
#
# ### **3. Limits and L'Hôpital's Rule**
# $
# \lim_{x \to 0} \frac{\sin x}{x} = 1
# $
#
# $
# \lim_{x \to 0} \frac{e^x - 1}{x} = 1
# $
#
# $
# \lim_{x \to \infty} \frac{x}{e^x} = 0
# $
#
# ---
#
# ### **4. Definite and Indefinite Integrals**
# $
# \int x^n \,dx = \frac{x^{n+1}}{n+1} + C, \quad n \neq -1
# $
#
# $
# \int_0^1 e^{-x} \,dx = 1 - e^{-1}
# $
#
# ---
#
# ### **5. Taylor Series of Common Functions**
# $
# e^x = \sum_{n=0}^{\infty} \frac{x^n}{n!}
# $
#
# $
# \sin x = \sum_{n=0}^{\infty} \frac{(-1)^n x^{2n+1}}{(2n+1)!}
# $
#
# $
# \cos x = \sum_{n=0}^{\infty} \frac{(-1)^n x^{2n}}{(2n)!}
# $
#
# ---

# %% [markdown]
# ```mermaid
# graph TD;
#     A[Start] --> B{Decision};
#     B -->|Yes| C[Continue];
#     B -->|No| D[Stop];

# %% [markdown]
# - $n! = n \times (n-1) \times (n-2) \times \cdots \times 1 $
# - $ P(n,r) = \frac {n!} {(n-r)!}  $
# - $ lim_{x \rightarrow 0} \frac {e^x -1}{x} =1 $

# %% [markdown]
# ### **6. Complex Numbers and Euler’s Formula**
# $
# e^{i\theta} = \cos \theta + i\sin \theta
# $
#
# $
# |z| = \sqrt{a^2 + b^2}, \quad \text{for } z = a + bi
# $
#
# ---
#
# ### **7. Probability and Statistics**
# $
# P(A \cup B) = P(A) + P(B) - P(A \cap B)
# $
#
# $
# E[X] = \sum_{i=1}^{n} x_i P(X = x_i)
# $
#
# $
# \text{Variance: } Var(X) = E[X^2] - (E[X])^2
# $
#
# ---
#
# ### **8. Matrices and Determinants**
# $
# A = \begin{bmatrix}
# a & b \\
# c & d
# \end{bmatrix}, \quad \det(A) = ad - bc
# $
#
# ---
#
# ### **9. Partial Derivatives**
# $
# \frac{\partial f}{\partial x}, \quad \frac{\partial^2 f}{\partial x^2}, \quad \frac{\partial^2 f}{\partial x \partial y}
# $
#
# ---
#
# ### **10. Differential Equations**
# $
# \frac{dy}{dx} + P(x)y = Q(x)
# $
#
# $
# y'' + py' + qy = 0
# $
#
# ---
